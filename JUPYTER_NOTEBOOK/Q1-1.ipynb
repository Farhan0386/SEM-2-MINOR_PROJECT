# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q1-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#   Book_ID                  Title               Author      Genre  \
# 0    B001            Don Quixote        Napoleon Hill    Romance
# 1    B002  To Kill a Mockingbird      Robert Kiyosaki  Biography
# 2    B003                   1984       Colleen Hoover    Fantasy
# 3    B004    Pride and Prejudice  F. Scott Fitzgerald  Self-Help
# 4    B005       The Great Gatsby       Colleen Hoover    Romance
#
#    Total_Borrows  Available_Copies
# 0            133                 3
# 1            147                 2
# 2            133                 1
# 3             85                 2
# 4             58                 6

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Book_ID           100 non-null    object
#  1   Title             100 non-null    object
#  2   Author            100 non-null    object
#  3   Genre             100 non-null    object
#  4   Total_Borrows     100 non-null    int64
#  5   Available_Copies  100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB
# None

# %%
print(df.describe())
# Out:
#        Total_Borrows  Available_Copies
# count     100.000000        100.000000
# mean       98.910000          5.240000
# std        30.907518          2.885421
# min        50.000000          1.000000
# 25%        73.250000          3.000000
# 50%        97.000000          5.500000
# 75%       126.000000          8.000000
# max       150.000000         10.000000

# %%
print(df.columns)
# Out:
# Index(['Book_ID', 'Title', 'Author', 'Genre', 'Total_Borrows',
#        'Available_Copies'],
#       dtype='object')

# %% [raw]
# print(pd.to_datetime(df['issue_date'], errors='coerce'))

# %%
print(df.shape)
# Out:
# (100, 6)

# %%
print(df.isnull().sum())
# Out:
# Book_ID             0
# Title               0
# Author              0
# Genre               0
# Total_Borrows       0
# Available_Copies    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Book_ID             object
# Title               object
# Author              object
# Genre               object
# Total_Borrows        int64
# Available_Copies     int64
# dtype: object
