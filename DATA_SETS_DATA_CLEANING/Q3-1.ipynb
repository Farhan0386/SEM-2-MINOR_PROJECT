# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q3-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#          Department  Total_Borrows  Total_Fines  Avg_Fine_per_User  \
# 0  Computer Science            520         3200                120
# 1        Mechanical            430         2800                110
# 2        Electrical            400         2600                105
# 3             Civil            350         2200                 95
# 4          Business            300         2500                115
#
#   Most_Borrowed_Genre  Late_Returns
# 0          Technology            85
# 1         Engineering            70
# 2          Technology            65
# 3         Engineering            60
# 4             Finance            55

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Department           10 non-null     object
#  1   Total_Borrows        10 non-null     int64
#  2   Total_Fines          10 non-null     int64
#  3   Avg_Fine_per_User    10 non-null     int64
#  4   Most_Borrowed_Genre  10 non-null     object
#  5   Late_Returns         10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 612.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Total_Borrows  Total_Fines  Avg_Fine_per_User  Late_Returns
# count      10.000000    10.000000          10.000000     10.000000
# mean      356.000000  2410.000000         104.500000     61.000000
# std        87.584879   527.994108          14.615441     13.490738
# min       240.000000  1500.000000          80.000000     40.000000
# 25%       285.000000  2125.000000          96.250000     51.250000
# 50%       360.000000  2450.000000         107.500000     61.000000
# 75%       407.500000  2750.000000         113.750000     68.750000
# max       520.000000  3200.000000         125.000000     85.000000

# %%
print(df.isnull().sum())
# Out:
# Department             0
# Total_Borrows          0
# Total_Fines            0
# Avg_Fine_per_User      0
# Most_Borrowed_Genre    0
# Late_Returns           0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Department', 'Total_Borrows', 'Total_Fines', 'Avg_Fine_per_User',
#        'Most_Borrowed_Genre', 'Late_Returns'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Department             object
# Total_Borrows           int64
# Total_Fines             int64
# Avg_Fine_per_User       int64
# Most_Borrowed_Genre    object
# Late_Returns            int64
# dtype: object
