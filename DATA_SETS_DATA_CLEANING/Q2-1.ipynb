# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q2-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#       Month  Year  Total_Borrows  Fiction  Non_Fiction  Academic  \
# 0   January  2025            420      150          120       100
# 1  February  2025            380      140          110        90
# 2     March  2025            450      160          130       110
# 3     April  2025            300      100           90        70
# 4       May  2025            180       70           50        40
#
#    Digital_Borrows
# 0               50
# 1               40
# 2               50
# 3               40
# 4               20

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Month            12 non-null     object
#  1   Year             12 non-null     int64
#  2   Total_Borrows    12 non-null     int64
#  3   Fiction          12 non-null     int64
#  4   Non_Fiction      12 non-null     int64
#  5   Academic         12 non-null     int64
#  6   Digital_Borrows  12 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 804.0+ bytes
# None

# %%
print(df.describe())
# Out:
#          Year  Total_Borrows     Fiction  Non_Fiction    Academic  \
# count    12.0      12.000000   12.000000    12.000000   12.000000
# mean   2025.0     326.666667  119.166667    95.000000   76.666667
# std       0.0     105.686787   36.793857    31.188576   28.069179
# min    2025.0     150.000000   60.000000    40.000000   30.000000
# 25%    2025.0     245.000000   87.500000    75.000000   55.000000
# 50%    2025.0     365.000000  135.000000   105.000000   85.000000
# 75%    2025.0     412.500000  150.000000   120.000000  100.000000
# max    2025.0     450.000000  160.000000   130.000000  110.000000
#
#        Digital_Borrows
# count        12.000000
# mean         35.833333
# std          10.836247
# min          20.000000
# 25%          27.500000
# 50%          40.000000
# 75%          40.000000
# max          50.000000

# %%
print(df.columns)
# Out:
# Index(['Month', 'Year', 'Total_Borrows', 'Fiction', 'Non_Fiction', 'Academic',
#        'Digital_Borrows'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (12, 7)

# %%
print(df.isnull().sum())
# Out:
# Month              0
# Year               0
# Total_Borrows      0
# Fiction            0
# Non_Fiction        0
# Academic           0
# Digital_Borrows    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Month              object
# Year                int64
# Total_Borrows       int64
# Fiction             int64
# Non_Fiction         int64
# Academic            int64
# Digital_Borrows     int64
# dtype: object
