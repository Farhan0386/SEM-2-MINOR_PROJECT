# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q4-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#   Late_Days_Range  Number_of_Students  Average_Fine
# 0        0-2 days                 120            10
# 1        3-5 days                  95            25
# 2       6-10 days                  70            50
# 3      11-15 days                  45            80
# 4      16-20 days                  25           120

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Late_Days_Range     6 non-null      object
#  1   Number_of_Students  6 non-null      int64
#  2   Average_Fine        6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 276.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Number_of_Students  Average_Fine
# count            6.000000      6.000000
# mean            61.666667     80.833333
# std             40.947120     70.456843
# min             15.000000     10.000000
# 25%             30.000000     31.250000
# 50%             57.500000     65.000000
# 75%             88.750000    110.000000
# max            120.000000    200.000000

# %%
print(df.isnull().sum())
# Out:
# Late_Days_Range       0
# Number_of_Students    0
# Average_Fine          0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Late_Days_Range', 'Number_of_Students', 'Average_Fine'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Late_Days_Range       object
# Number_of_Students     int64
# Average_Fine           int64
# dtype: object
