# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q3-2.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#          Department  Total_Borrows  Late_Returns  Total_Fines  Max_Fine  \
# 0  Computer Science            571            75         3375       184
# 1        Mechanical            414            97         4753       108
# 2        Electrical            545            93         2697       181
# 3             Civil            577            89         3560       160
# 4          Business            527            75         2700       116
#
#    Min_Fine  Avg_Fine
# 0        11        45
# 1        20        49
# 2         5        29
# 3        12        40
# 4        13        36

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Department     10 non-null     object
#  1   Total_Borrows  10 non-null     int64
#  2   Late_Returns   10 non-null     int64
#  3   Total_Fines    10 non-null     int64
#  4   Max_Fine       10 non-null     int64
#  5   Min_Fine       10 non-null     int64
#  6   Avg_Fine       10 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 692.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Total_Borrows  Late_Returns  Total_Fines    Max_Fine   Min_Fine  \
# count      10.000000     10.000000    10.000000   10.000000  10.000000
# mean      476.300000     74.700000  2646.200000  134.600000  13.300000
# std        88.859502     17.133787  1096.567351   35.472055   4.217688
# min       334.000000     50.000000  1000.000000   92.000000   5.000000
# 25%       398.250000     60.000000  2355.250000  110.000000  11.250000
# 50%       514.000000     76.000000  2580.500000  118.000000  13.000000
# 75%       540.500000     87.750000  3206.250000  168.250000  16.000000
# max       577.000000     97.000000  4753.000000  184.000000  20.000000
#
#         Avg_Fine
# count  10.000000
# mean   34.500000
# std     9.698224
# min    20.000000
# 25%    28.250000
# 50%    34.000000
# 75%    42.250000
# max    49.000000

# %%
print(df.isnull().sum())
# Out:
# Department       0
# Total_Borrows    0
# Late_Returns     0
# Total_Fines      0
# Max_Fine         0
# Min_Fine         0
# Avg_Fine         0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Department', 'Total_Borrows', 'Late_Returns', 'Total_Fines',
#        'Max_Fine', 'Min_Fine', 'Avg_Fine'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Department       object
# Total_Borrows     int64
# Late_Returns      int64
# Total_Fines       int64
# Max_Fine          int64
# Min_Fine          int64
# Avg_Fine          int64
# dtype: object
