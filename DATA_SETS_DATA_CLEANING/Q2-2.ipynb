# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q2-2.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#       Month  Year  Total_Borrows  Fiction  Non_Fiction  Academic  \
# 0   January  2025            390      140          110        90
# 1  February  2025            360      130          100        85
# 2     March  2025            470      170          140       110
# 3     April  2025            320      110           95        75
# 4       May  2025            200       80           60        40
#
#    Digital_Borrows
# 0               50
# 1               45
# 2               50
# 3               40
# 4               20

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Month            12 non-null     object
#  1   Year             12 non-null     int64
#  2   Total_Borrows    12 non-null     int64
#  3   Fiction          12 non-null     int64
#  4   Non_Fiction      12 non-null     int64
#  5   Academic         12 non-null     int64
#  6   Digital_Borrows  12 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 804.0+ bytes
# None

# %%
print(df.describe())
# Out:
#          Year  Total_Borrows     Fiction  Non_Fiction    Academic  \
# count    12.0      12.000000   12.000000    12.000000   12.000000
# mean   2025.0     340.833333  125.833333   100.833333   77.916667
# std       0.0     103.084990   35.021638    30.063065   28.798543
# min    2025.0     170.000000   70.000000    50.000000   30.000000
# 25%    2025.0     265.000000   97.500000    81.250000   58.750000
# 50%    2025.0     365.000000  135.000000   105.000000   82.500000
# 75%    2025.0     417.500000  152.500000   122.500000  102.500000
# max    2025.0     470.000000  170.000000   140.000000  110.000000
#
#        Digital_Borrows
# count        12.000000
# mean         36.250000
# std          11.103849
# min          20.000000
# 25%          27.500000
# 50%          40.000000
# 75%          41.250000
# max          50.000000

# %%
print(df.isnull().sum())
# Out:
# Month              0
# Year               0
# Total_Borrows      0
# Fiction            0
# Non_Fiction        0
# Academic           0
# Digital_Borrows    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Month', 'Year', 'Total_Borrows', 'Fiction', 'Non_Fiction', 'Academic',
#        'Digital_Borrows'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Month              object
# Year                int64
# Total_Borrows       int64
# Fiction             int64
# Non_Fiction         int64
# Academic            int64
# Digital_Borrows     int64
# dtype: object

# %% [raw]
# print(df.shape)
