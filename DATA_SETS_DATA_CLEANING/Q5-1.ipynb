# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q5-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#   Student_ID        Department Book_ID  Days_Borrowed  Due_Days  Days_Late  \
# 0       S001  Computer Science    B001             15        10          5
# 1       S002        Mechanical    B002              8        10          0
# 2       S003        Electrical    B003             12        10          2
# 3       S004             Civil    B004              9        10          0
# 4       S005          Business    B005             18        10          8
#
#    Previous_Late_Returns  Total_Borrows  Fine_Amount Fined
# 0                      2             12           50   Yes
# 1                      0              8            0    No
# 2                      1             10           20   Yes
# 3                      0              6            0    No
# 4                      3             15           80   Yes

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             20 non-null     object
#  1   Department             20 non-null     object
#  2   Book_ID                20 non-null     object
#  3   Days_Borrowed          20 non-null     int64
#  4   Due_Days               20 non-null     int64
#  5   Days_Late              20 non-null     int64
#  6   Previous_Late_Returns  20 non-null     int64
#  7   Total_Borrows          20 non-null     int64
#  8   Fine_Amount            20 non-null     int64
#  9   Fined                  20 non-null     object
# dtypes: int64(6), object(4)
# memory usage: 1.7+ KB
# None

# %%
print(df.describe())
# Out:
#        Days_Borrowed  Due_Days  Days_Late  Previous_Late_Returns  \
# count      20.000000      20.0  20.000000              20.000000
# mean       12.050000      10.0   2.950000               1.450000
# std         4.430457       0.0   3.516502               1.394538
# min         6.000000      10.0   0.000000               0.000000
# 25%         8.000000      10.0   0.000000               0.000000
# 50%        11.000000      10.0   1.000000               1.000000
# 75%        15.250000      10.0   5.250000               2.250000
# max        20.000000      10.0  10.000000               4.000000
#
#        Total_Borrows  Fine_Amount
# count      20.000000    20.000000
# mean        9.650000    29.500000
# std         4.246051    35.165024
# min         4.000000     0.000000
# 25%         6.000000     0.000000
# 50%         9.500000    10.000000
# 75%        12.250000    52.500000
# max        18.000000   100.000000

# %%
print(df.isnull().sum())
# Out:
# Student_ID               0
# Department               0
# Book_ID                  0
# Days_Borrowed            0
# Due_Days                 0
# Days_Late                0
# Previous_Late_Returns    0
# Total_Borrows            0
# Fine_Amount              0
# Fined                    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Department', 'Book_ID', 'Days_Borrowed', 'Due_Days',
#        'Days_Late', 'Previous_Late_Returns', 'Total_Borrows', 'Fine_Amount',
#        'Fined'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Student_ID               object
# Department               object
# Book_ID                  object
# Days_Borrowed             int64
# Due_Days                  int64
# Days_Late                 int64
# Previous_Late_Returns     int64
# Total_Borrows             int64
# Fine_Amount               int64
# Fined                    object
# dtype: object
