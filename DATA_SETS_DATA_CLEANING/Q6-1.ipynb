# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q6-1.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#   Query_ID     Query_Type            Example_Query Frequency_Level
# 0     Q001   Fine Related            Fine per day?             Low
# 1     Q002   Library Info              Open today?             Low
# 2     Q003   Account Info         My issued books?          Medium
# 3     Q004  Borrow/Return  How many books allowed?            High
# 4     Q005   Fine Related             Any penalty?          Medium

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Query_ID         100 non-null    object
#  1   Query_Type       100 non-null    object
#  2   Example_Query    100 non-null    object
#  3   Frequency_Level  100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB
# None

# %%
print(df.describe())
# Out:
#        Query_ID     Query_Type         Example_Query Frequency_Level
# count       100            100                   100             100
# unique      100              6                    30               3
# top        Q001  Borrow/Return  What is my due date?             Low
# freq          1             20                     7              34

# %%
print(df.isnull().sum())
# Out:
# Query_ID           0
# Query_Type         0
# Example_Query      0
# Frequency_Level    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Query_ID', 'Query_Type', 'Example_Query', 'Frequency_Level'], dtype='object')

# %%
print(df.dtypes)
