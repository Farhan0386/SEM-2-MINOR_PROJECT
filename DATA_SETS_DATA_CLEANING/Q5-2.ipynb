# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../DATA_SETS/q5-2.xlsx", engine="openpyxl")

# %%
print(df.head())
# Out:
#   Student_ID        Department Book_ID  Days_Borrowed  Due_Days  Days_Late  \
# 0       S001        Mechanical    B002             10        10          0
# 1       S002             Civil    B001              9        10          0
# 2       S003  Computer Science    B003             18        10          8
# 3       S004        Electrical    B004             13        10          3
# 4       S005        Mechanical    B004              5        10          0
#
#    Previous_Late_Returns  Total_Borrows  Fine_Amount Fined
# 0                      2              5            0    No
# 1                      0             16            0    No
# 2                      2             15          112   Yes
# 3                      2             10           36   Yes
# 4                      3             15            0    No

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     object
#  1   Department             25 non-null     object
#  2   Book_ID                25 non-null     object
#  3   Days_Borrowed          25 non-null     int64
#  4   Due_Days               25 non-null     int64
#  5   Days_Late              25 non-null     int64
#  6   Previous_Late_Returns  25 non-null     int64
#  7   Total_Borrows          25 non-null     int64
#  8   Fine_Amount            25 non-null     int64
#  9   Fined                  25 non-null     object
# dtypes: int64(6), object(4)
# memory usage: 2.1+ KB
# None

# %%
print(df.describe())
# Out:
#        Days_Borrowed  Due_Days  Days_Late  Previous_Late_Returns  \
# count      25.000000      25.0  25.000000              25.000000
# mean       12.920000      10.0   3.760000               1.840000
# std         4.957486       0.0   3.810949               1.106044
# min         5.000000      10.0   0.000000               0.000000
# 25%        10.000000      10.0   0.000000               1.000000
# 50%        12.000000      10.0   2.000000               2.000000
# 75%        18.000000      10.0   8.000000               3.000000
# max        20.000000      10.0  10.000000               4.000000
#
#        Total_Borrows  Fine_Amount
# count      25.000000      25.0000
# mean       10.880000      38.7600
# std         4.807286      45.5762
# min         3.000000       0.0000
# 25%         7.000000       0.0000
# 50%        11.000000      22.0000
# 75%        15.000000      60.0000
# max        18.000000     140.0000

# %%
print(df.isnull().sum())
# Out:
# Student_ID               0
# Department               0
# Book_ID                  0
# Days_Borrowed            0
# Due_Days                 0
# Days_Late                0
# Previous_Late_Returns    0
# Total_Borrows            0
# Fine_Amount              0
# Fined                    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Department', 'Book_ID', 'Days_Borrowed', 'Due_Days',
#        'Days_Late', 'Previous_Late_Returns', 'Total_Borrows', 'Fine_Amount',
#        'Fined'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Student_ID               object
# Department               object
# Book_ID                  object
# Days_Borrowed             int64
# Due_Days                  int64
# Days_Late                 int64
# Previous_Late_Returns     int64
# Total_Borrows             int64
# Fine_Amount               int64
# Fined                    object
# dtype: object
