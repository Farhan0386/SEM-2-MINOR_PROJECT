# %%
import pandas as pd
df=pd.read_excel("q1-1.xlsx", engine="openpyxl")

# %%
top_books=df['Title'].value_counts().head(6)
print(top_books)
# Out:
# Title
# Don Quixote                        1
# The Sun Also Rises                 1
# Divergent                          1
# The Hunger Games                   1
# The Da Vinci Code                  1
# The Girl with the Dragon Tattoo    1
# Name: count, dtype: int64

# %%
top
